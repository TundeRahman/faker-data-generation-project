# %%
import duckdb

# %%
duckdb.read_csv("extracted_data.csv")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 duckdb.read_csv("extracted_data.csv")
#
# IOException: IO Error: No files found that match the pattern "extracted_data.csv"

# %%
duckdb.read_csv("/Users/babatunderahman/Documents/Data Analytics/Data Engineering/Dagster/Faker Project/faker-data-generation-project/data/raw/extracted_data.csv")
# Out:
# ┌──────────────────────────────┬────────────────┬─────────────┬─────────┬───────────────┬────────────────────────────────────────────────────────────┬────────────────────────────┐
# │         product_name         │   brand_name   │     SKU     │  price  │   order_id    │                    product_description                     │     data_generated_at      │
# │           varchar            │    varchar     │   varchar   │ varchar │    varchar    │                          varchar                           │         timestamp          │
# ├──────────────────────────────┼────────────────┼─────────────┼─────────┼───────────────┼────────────────────────────────────────────────────────────┼────────────────────────────┤
# │ Ergonomic Gaming Chair       │ Samsung        │ YNT-1312-NB │ $492.08 │ ORD-419712930 │ A waterproof yoga mat made with high-quality nylon.        │ 2026-07-20 22:50:44.933528 │
# ...

# %%
duckdb.read_csv("/Users/babatunderahman/Documents/Data Analytics/Data Engineering/Dagster/Faker Project/faker-data-generation-project/data/raw/customer_data.csv")
# Out:
# ┌─────────────────────┬────────────────────────────┬────────────────────────┬───────────────────────────────────────────────────────────────┐
# │    customer_name    │           email            │         phone          │                            address                            │
# │       varchar       │          varchar           │        varchar         │                            varchar                            │
# ├─────────────────────┼────────────────────────────┼────────────────────────┼───────────────────────────────────────────────────────────────┤
# │ Kelly Miller        │ kristine29@example.org     │ 001-433-739-0675       │ 323 Christine Camp\nWest Patricia, VI 53828                   │
# │ Aimee Jones         │ david53@example.org        │ 730-788-6139           │ 90305 Jacobs Cliff\nEast Justinhaven, CT 63723                │
# ...
