# %%
import duckdb

# %%
duckdb.read_csv("extracted_data.csv")
# Out:
# ┌───────────────────────────────┬─────────────┬─────────────┬─────────┬────────────────────────────┐
# │         product_name          │ brand_name  │     SKU     │  price  │     data_generated_at      │
# │            varchar            │   varchar   │   varchar   │ varchar │         timestamp          │
# ├───────────────────────────────┼─────────────┼─────────────┼─────────┼────────────────────────────┤
# │ Organic Smartphone            │ Xiaomi      │ ILF-8243-QJ │ $830.45 │ 2026-07-20 09:19:09.856931 │
# │ Smart Drone                   │ Panasonic   │ UWM-1279-ZM │ $436.73 │ 2026-07-20 09:19:09.857569 │
# │ Professional Power Bank       │ Bose        │ RPU-2848-EH │ $87.39  │ 2026-07-20 09:19:09.857584 │
# │ Classic Headphones            │ Puma        │ XFU-1927-BJ │ $69.16  │ 2026-07-20 09:19:09.857595 │
# │ Modern Vacuum Cleaner         │ Anker       │ GUF-6073-BH │ $481.37 │ 2026-07-20 09:19:09.857606 │
# ...
